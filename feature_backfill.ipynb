# %% [markdown]
# # Environment

# %%
import sys
from pathlib import Path
import warnings
warnings.filterwarnings("ignore", module="IPython")

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

print(f"Root dir: {root_dir}")

# Add the root directory to the `PYTHONPATH` 
if root_dir not in sys.path:
    sys.path.append(root_dir)
    print(f"Added the following directory to the PYTHONPATH: {root_dir}")
# Out:
# Local environment
# Root dir: /Users/cuiyuting/Desktop/release_popularity_prediction

# %%
import datetime
import requests
import pandas as pd
import hopsworks
import datetime
from pathlib import Path
import json
import re
import os
import warnings
warnings.filterwarnings("ignore")

# %%
project = hopsworks.login()
# Out:
# 2026-01-11 16:46:59,226 INFO: Closing external client and cleaning up certificates.
# Connection closed.
# 2026-01-11 16:46:59,375 INFO: Initializing external client
# 2026-01-11 16:46:59,377 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2026-01-11 16:47:01,344 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1342613

# %% [markdown]
# # Trending Info
# ## Read CSV into Dataframe

# %%
today = datetime.date.today()

trending_csv_file=f"{root_dir}/data/trending_history_with_topics.csv"

trending_df_original = pd.read_csv(trending_csv_file, skipinitialspace=True)
trending_df_original
# Out:
#             date                               repo_name  new_stars  rank  \
# 0     2026-01-10                      anomalyco/opencode       1052     1
# 1     2026-01-10                  kepano/obsidian-skills        490     2
# 2     2026-01-10                        obra/superpowers        378     3
# 3     2026-01-10             code-yeongyu/oh-my-opencode        316     4
# 4     2026-01-10         ChrisWiles/claude-code-showcase        304     5
# ...          ...                                     ...        ...   ...
# 3745  2025-01-01                      bytedance/monolith        576     6
# 3746  2025-01-01                  huggingface/smolagents        501     7
# 3747  2025-01-01  EbookFoundation/free-programming-books        428     8
# 3748  2025-01-01               DigitalPlatDev/FreeDomain        426     9
# 3749  2025-01-01           DrewThomasson/ebook2audiobook        419    10
#
#                                                  topics
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     ['ai', 'ai-agents', 'amp', 'anthropic', 'chatg...
# 4                                                    []
# ...                                                 ...
# 3745                                                 []
# 3746                                                 []
# 3747  ['books', 'education', 'hacktoberfest', 'list'...
# 3748  ['digitalplat', 'domain', 'domain-platform', '...
# 3749  ['audiobook', 'audiobooks', 'chinese', 'colab-...
#
# [3750 rows x 5 columns]

# %%
trending_df_original.dtypes
# Out:
# date         object
# repo_name    object
# new_stars     int64
# rank          int64
# topics       object
# dtype: object

# %% [markdown]
# ## Feature Engineering

# %%
# discard useless columns
trending_df = trending_df_original[['date', 'topics']]
trending_df
# Out:
#             date                                             topics
# 0     2026-01-10                                                 []
# 1     2026-01-10                                                 []
# 2     2026-01-10                                                 []
# 3     2026-01-10  ['ai', 'ai-agents', 'amp', 'anthropic', 'chatg...
# 4     2026-01-10                                                 []
# ...          ...                                                ...
# 3745  2025-01-01                                                 []
# 3746  2025-01-01                                                 []
# 3747  2025-01-01  ['books', 'education', 'hacktoberfest', 'list'...
# 3748  2025-01-01  ['digitalplat', 'domain', 'domain-platform', '...
# 3749  2025-01-01  ['audiobook', 'audiobooks', 'chinese', 'colab-...
#
# [3750 rows x 2 columns]

# %%
# transforming data type
def parse_topics(topic_str):
    if ',' in topic_str:
        return [t.strip() for t in topic_str.split(',')]
    else:
        return [topic_str.strip()]

trending_df['topics'] = trending_df['topics'].apply(parse_topics)
trending_df['date'] = pd.to_datetime(trending_df['date'])
trending_df
# Out:
#            date                                             topics
# 0    2026-01-10                                               [[]]
# 1    2026-01-10                                               [[]]
# 2    2026-01-10                                               [[]]
# 3    2026-01-10  [['ai', 'ai-agents', 'amp', 'anthropic', 'chat...
# 4    2026-01-10                                               [[]]
# ...         ...                                                ...
# 3745 2025-01-01                                               [[]]
# 3746 2025-01-01                                               [[]]
# 3747 2025-01-01  [['books', 'education', 'hacktoberfest', 'list...
# 3748 2025-01-01  [['digitalplat', 'domain', 'domain-platform', ...
# 3749 2025-01-01  [['audiobook', 'audiobooks', 'chinese', 'colab...
#
# [3750 rows x 2 columns]

# %%
# Aggregate topics by date
def aggregate_topics(group):
    all_topics = []
    for topics in group:
        all_topics.extend(topics)
    return list(set(all_topics))

daily_topics_df = trending_df.groupby('date')['topics'].apply(aggregate_topics).reset_index()
daily_topics_df.columns = ['date', 'all_topics']

daily_topics_df
# Out:
#           date                                         all_topics
# 0   2025-01-01  ['docker', 'education', 'tts', 'hacktoberfest'...
# 1   2025-01-02  ['chatgpt', 'minecraft', 'tutorial-code', 'fre...
# 2   2025-01-03  ['nlp', 'minecraft', 'tutorial-code', 'free', ...
# 3   2025-01-04  ['swarm', 'nlp', 'tutorial-code', 'minecraft',...
# 4   2025-01-05  ['obsidian', 'image-generation', 'nlp', 'chatg...
# ..         ...                                                ...
# 370 2026-01-06  ['landing-page', 'artificial-intelligence', 'e...
# 371 2026-01-07  ['landing-page', 'artificial-intelligence', 'e...
# 372 2026-01-08  ['landing-page', 'chatgpt', 'orchestration', '...
# 373 2026-01-09  ['landing-page', 'daisydisk', 'chatgpt', 'orch...
# 374 2026-01-10  ['chatgpt', 'orchestration', 'gemini', 'openco...
#
# [375 rows x 2 columns]

# %% [markdown]
# ## Create Feature Groups and insert DataFrames

# %%
fs = project.get_feature_store()

# %%
trending_fg = fs.get_or_create_feature_group(
    name='trending_info',
    description='Github trending repository topics aggrated daily',
    version=1,
    primary_key=['date'],
    event_time="date"
)

# %%
trending_fg.insert(daily_topics_df)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1342613/fs/1331268/fg/1938762
# Uploading Dataframe: 100.00% |██████████| Rows 375/375 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: trending_info_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1342613/jobs/named/trending_info_1_offline_fg_materialization/executions
# (Job('trending_info_1_offline_fg_materialization', 'SPARK'), None)

# %% [markdown]
# # Release Info
# ## Read CSV into Dataframe

# %%
today = datetime.date.today()

release_csv_file=f"{root_dir}/data/release_raw_data.csv"

release_df_original = pd.read_csv(release_csv_file, skipinitialspace=True)
release_df_original
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language       repo_created_at       repo_updated_at  \
# 0               113      CSS  2025-09-06T22:08:06Z  2026-01-09T15:00:36Z
# 1               113      CSS  2025-09-06T22:08:06Z  2026-01-09T15:00:36Z
# 2               113      CSS  2025-09-06T22:08:06Z  2026-01-09T15:00:36Z
# 3               113      CSS  2025-09-06T22:08:06Z  2026-01-09T15:00:36Z
# 4               113      CSS  2025-09-06T22:08:06Z  2026-01-09T15:00:36Z
# ...             ...      ...                   ...                   ...
# 4044           1367   Python  2025-08-04T15:10:45Z  2026-01-09T22:45:43Z
# 4045           1367   Python  2025-08-04T15:10:45Z  2026-01-09T22:45:43Z
# 4046           1367   Python  2025-08-04T15:10:45Z  2026-01-09T22:45:43Z
# 4047           1367   Python  2025-08-04T15:10:45Z  2026-01-09T22:45:43Z
# 4048           1362        C  2025-11-04T10:38:17Z  2026-01-09T23:46:56Z
#
#                                                  topics release_name  \
# 0                                                    []       v2.1.4
# 1                                                    []       v2.1.3
# 2                                                    []       v2.1.2
# 3                                                    []       v2.1.1
# 4                                                    []       v2.1.0
# ...                                                 ...          ...
# 4044  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v1.2.0
# 4045  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v1.1.0
# 4046  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v1.0.0
# 4047  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v0.2.0
# 4048                                                 []   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos   author_type          published_at  prerelease  \
# 0                      21          User  2026-01-08T20:07:56Z       False
# 1                      21          User  2026-01-05T23:56:48Z       False
# 2                      21          User  2026-01-03T22:20:14Z       False
# 3                      21          User  2026-01-02T20:03:09Z       False
# 4                      21          User  2026-01-02T14:25:38Z       False
# ...                   ...           ...                   ...         ...
# 4044                    1          User  2025-10-04T11:01:46Z       False
# 4045                    1          User  2025-09-20T13:40:38Z       False
# 4046                    1          User  2025-09-16T17:21:47Z       False
# 4047                    1          User  2025-09-13T10:07:39Z       False
# 4048                  440  Organization  2025-12-04T10:29:19Z        True
#
#       draft  first_week_star
# 0     False                3
# 1     False               11
# 2     False               12
# 3     False               14
# 4     False               15
# ...     ...              ...
# 4044  False               61
# 4045  False               32
# 4046  False               63
# 4047  False              125
# 4048  False               20
#
# [4049 rows x 17 columns]

# %%
release_df_original.dtypes
# Out:
# full_name              object
# repo_stars              int64
# repo_forks              int64
# repo_watchers           int64
# language               object
# repo_created_at        object
# repo_updated_at        object
# topics                 object
# release_name           object
# release_body           object
# author_followers        int64
# author_public_repos     int64
# author_type            object
# published_at           object
# prerelease               bool
# draft                    bool
# first_week_star         int64
# dtype: object

# %%
date_cols = ['repo_created_at', 'repo_updated_at', 'published_at']
for col in date_cols:
    release_df_original[col] = pd.to_datetime(release_df_original[col])
release_df_original.dtypes
# Out:
# full_name                           object
# repo_stars                           int64
# repo_forks                           int64
# repo_watchers                        int64
# language                            object
# repo_created_at        datetime64[ns, UTC]
# repo_updated_at        datetime64[ns, UTC]
# topics                              object
# release_name                        object
# release_body                        object
# author_followers                     int64
# author_public_repos                  int64
# author_type                         object
# published_at           datetime64[ns, UTC]
# prerelease                            bool
# draft                                 bool
# first_week_star                      int64
# dtype: object

# %% [markdown]
# ## Feature Engineering

# %%
# almost all False in the dataset
release_df = release_df_original.drop(columns=['prerelease', 'draft'])
release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language           repo_created_at  \
# 0               113      CSS 2025-09-06 22:08:06+00:00
# 1               113      CSS 2025-09-06 22:08:06+00:00
# 2               113      CSS 2025-09-06 22:08:06+00:00
# 3               113      CSS 2025-09-06 22:08:06+00:00
# 4               113      CSS 2025-09-06 22:08:06+00:00
# ...             ...      ...                       ...
# 4044           1367   Python 2025-08-04 15:10:45+00:00
# 4045           1367   Python 2025-08-04 15:10:45+00:00
# 4046           1367   Python 2025-08-04 15:10:45+00:00
# 4047           1367   Python 2025-08-04 15:10:45+00:00
# 4048           1362        C 2025-11-04 10:38:17+00:00
#
#                repo_updated_at  \
# 0    2026-01-09 15:00:36+00:00
# 1    2026-01-09 15:00:36+00:00
# 2    2026-01-09 15:00:36+00:00
# 3    2026-01-09 15:00:36+00:00
# 4    2026-01-09 15:00:36+00:00
# ...                        ...
# 4044 2026-01-09 22:45:43+00:00
# 4045 2026-01-09 22:45:43+00:00
# 4046 2026-01-09 22:45:43+00:00
# 4047 2026-01-09 22:45:43+00:00
# 4048 2026-01-09 23:46:56+00:00
#
#                                                  topics release_name  \
# 0                                                    []       v2.1.4
# 1                                                    []       v2.1.3
# 2                                                    []       v2.1.2
# 3                                                    []       v2.1.1
# 4                                                    []       v2.1.0
# ...                                                 ...          ...
# 4044  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v1.2.0
# 4045  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v1.1.0
# 4046  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v1.0.0
# 4047  ['atlassian', 'atlassian-jira', 'cli', 'develo...       v0.2.0
# 4048                                                 []   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos   author_type              published_at  \
# 0                      21          User 2026-01-08 20:07:56+00:00
# 1                      21          User 2026-01-05 23:56:48+00:00
# 2                      21          User 2026-01-03 22:20:14+00:00
# 3                      21          User 2026-01-02 20:03:09+00:00
# 4                      21          User 2026-01-02 14:25:38+00:00
# ...                   ...           ...                       ...
# 4044                    1          User 2025-10-04 11:01:46+00:00
# 4045                    1          User 2025-09-20 13:40:38+00:00
# 4046                    1          User 2025-09-16 17:21:47+00:00
# 4047                    1          User 2025-09-13 10:07:39+00:00
# 4048                  440  Organization 2025-12-04 10:29:19+00:00
#
#       first_week_star
# 0                   3
# 1                  11
# 2                  12
# 3                  14
# 4                  15
# ...               ...
# 4044               61
# 4045               32
# 4046               63
# 4047              125
# 4048               20
#
# [4049 rows x 15 columns]

# %%
# Trending feature
def parse_topics(topic_str):
    if ',' in topic_str:
        return [t.strip() for t in topic_str.split(',')]
    else:
        return [topic_str.strip()]

release_df['topics'] = release_df['topics'].apply(parse_topics)
release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language           repo_created_at  \
# 0               113      CSS 2025-09-06 22:08:06+00:00
# 1               113      CSS 2025-09-06 22:08:06+00:00
# 2               113      CSS 2025-09-06 22:08:06+00:00
# 3               113      CSS 2025-09-06 22:08:06+00:00
# 4               113      CSS 2025-09-06 22:08:06+00:00
# ...             ...      ...                       ...
# 4044           1367   Python 2025-08-04 15:10:45+00:00
# 4045           1367   Python 2025-08-04 15:10:45+00:00
# 4046           1367   Python 2025-08-04 15:10:45+00:00
# 4047           1367   Python 2025-08-04 15:10:45+00:00
# 4048           1362        C 2025-11-04 10:38:17+00:00
#
#                repo_updated_at  \
# 0    2026-01-09 15:00:36+00:00
# 1    2026-01-09 15:00:36+00:00
# 2    2026-01-09 15:00:36+00:00
# 3    2026-01-09 15:00:36+00:00
# 4    2026-01-09 15:00:36+00:00
# ...                        ...
# 4044 2026-01-09 22:45:43+00:00
# 4045 2026-01-09 22:45:43+00:00
# 4046 2026-01-09 22:45:43+00:00
# 4047 2026-01-09 22:45:43+00:00
# 4048 2026-01-09 23:46:56+00:00
#
#                                                  topics release_name  \
# 0                                                  [[]]       v2.1.4
# 1                                                  [[]]       v2.1.3
# 2                                                  [[]]       v2.1.2
# 3                                                  [[]]       v2.1.1
# 4                                                  [[]]       v2.1.0
# ...                                                 ...          ...
# 4044  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v1.2.0
# 4045  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v1.1.0
# 4046  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v1.0.0
# 4047  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v0.2.0
# 4048                                               [[]]   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos   author_type              published_at  \
# 0                      21          User 2026-01-08 20:07:56+00:00
# 1                      21          User 2026-01-05 23:56:48+00:00
# 2                      21          User 2026-01-03 22:20:14+00:00
# 3                      21          User 2026-01-02 20:03:09+00:00
# 4                      21          User 2026-01-02 14:25:38+00:00
# ...                   ...           ...                       ...
# 4044                    1          User 2025-10-04 11:01:46+00:00
# 4045                    1          User 2025-09-20 13:40:38+00:00
# 4046                    1          User 2025-09-16 17:21:47+00:00
# 4047                    1          User 2025-09-13 10:07:39+00:00
# 4048                  440  Organization 2025-12-04 10:29:19+00:00
#
#       first_week_star
# 0                   3
# 1                  11
# 2                  12
# 3                  14
# 4                  15
# ...               ...
# 4044               61
# 4045               32
# 4046               63
# 4047              125
# 4048               20
#
# [4049 rows x 15 columns]

# %%
trending_df = trending_fg.read()
trending_df
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (2.65s)
#                          date  \
# 0   2025-05-09 00:00:00+00:00
# 1   2025-09-16 00:00:00+00:00
# 2   2025-01-07 00:00:00+00:00
# 3   2025-06-19 00:00:00+00:00
# 4   2025-10-03 00:00:00+00:00
# ..                        ...
# 370 2025-10-20 00:00:00+00:00
# 371 2025-12-17 00:00:00+00:00
# 372 2025-06-27 00:00:00+00:00
# 373 2025-09-29 00:00:00+00:00
# 374 2025-04-23 00:00:00+00:00
#
#                                             all_topics
# 0    ['chatgpt', 'domain', 'github', [], 'node-base...
# 1    ['spec', 'tts', 'chatgpt', 'generative-ai', 'd...
# 2    ['obsidian', 'artificial-intelligence', 'image...
# 3    ['shadcn-ui', 'etl-framework', 'claude-usage',...
# 4    ['decentralized', 'enterprise', 'workflow-auto...
# ..                                                 ...
# 370  ['chineseocr', 'pp-ocr', 'spec', 'insomnia-alt...
# 371  ['artificial-intelligence', 'daisydisk', 'phon...
# 372  ['hacktoberfest', 'web'], 'chatgpt', 'browser'...
# 373  ['spec', 'chatgpt', 'windows'], 'dba-roadmap',...
# 374  ['hacktoberfest', 'github-copilot', 'free-cert...
#
# [375 rows x 2 columns]

# %%
release_topics_df = release_df.copy()
trending_topics_df = trending_df.copy()
release_topics_df['date_only'] = pd.to_datetime(release_df['published_at']).dt.date
trending_topics_df['date'] = pd.to_datetime(trending_topics_df['date']).dt.date

topic_map = {row['date']: set(row['all_topics']) for _, row in trending_topics_df.iterrows()}

release_topics_df['is_trending'] = release_topics_df.apply(
    lambda row: bool(set(row['topics']) & topic_map.get(row['date_only'], set())),
    axis=1
)

print(f"Success Matching: {release_topics_df['is_trending'].sum()} / {len(release_topics_df)}")
release_topics_df
# Out:
# Success Matching: 2496 / 4049
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language           repo_created_at  \
# 0               113      CSS 2025-09-06 22:08:06+00:00
# 1               113      CSS 2025-09-06 22:08:06+00:00
# 2               113      CSS 2025-09-06 22:08:06+00:00
# 3               113      CSS 2025-09-06 22:08:06+00:00
# 4               113      CSS 2025-09-06 22:08:06+00:00
# ...             ...      ...                       ...
# 4044           1367   Python 2025-08-04 15:10:45+00:00
# 4045           1367   Python 2025-08-04 15:10:45+00:00
# 4046           1367   Python 2025-08-04 15:10:45+00:00
# 4047           1367   Python 2025-08-04 15:10:45+00:00
# 4048           1362        C 2025-11-04 10:38:17+00:00
#
#                repo_updated_at  \
# 0    2026-01-09 15:00:36+00:00
# 1    2026-01-09 15:00:36+00:00
# 2    2026-01-09 15:00:36+00:00
# 3    2026-01-09 15:00:36+00:00
# 4    2026-01-09 15:00:36+00:00
# ...                        ...
# 4044 2026-01-09 22:45:43+00:00
# 4045 2026-01-09 22:45:43+00:00
# 4046 2026-01-09 22:45:43+00:00
# 4047 2026-01-09 22:45:43+00:00
# 4048 2026-01-09 23:46:56+00:00
#
#                                                  topics release_name  \
# 0                                                  [[]]       v2.1.4
# 1                                                  [[]]       v2.1.3
# 2                                                  [[]]       v2.1.2
# 3                                                  [[]]       v2.1.1
# 4                                                  [[]]       v2.1.0
# ...                                                 ...          ...
# 4044  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v1.2.0
# 4045  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v1.1.0
# 4046  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v1.0.0
# 4047  [['atlassian', 'atlassian-jira', 'cli', 'devel...       v0.2.0
# 4048                                               [[]]   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos   author_type              published_at  \
# 0                      21          User 2026-01-08 20:07:56+00:00
# 1                      21          User 2026-01-05 23:56:48+00:00
# 2                      21          User 2026-01-03 22:20:14+00:00
# 3                      21          User 2026-01-02 20:03:09+00:00
# 4                      21          User 2026-01-02 14:25:38+00:00
# ...                   ...           ...                       ...
# 4044                    1          User 2025-10-04 11:01:46+00:00
# 4045                    1          User 2025-09-20 13:40:38+00:00
# 4046                    1          User 2025-09-16 17:21:47+00:00
# 4047                    1          User 2025-09-13 10:07:39+00:00
# 4048                  440  Organization 2025-12-04 10:29:19+00:00
#
#       first_week_star   date_only  is_trending
# 0                   3  2026-01-08         True
# 1                  11  2026-01-05         True
# 2                  12  2026-01-03         True
# 3                  14  2026-01-02         True
# 4                  15  2026-01-02         True
# ...               ...         ...          ...
# 4044               61  2025-10-04         True
# 4045               32  2025-09-20        False
# 4046               63  2025-09-16         True
# 4047              125  2025-09-13         True
# 4048               20  2025-12-04         True
#
# [4049 rows x 17 columns]

# %%
release_topics_df = release_topics_df.drop(columns=['topics'])
release_df = release_topics_df
release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language           repo_created_at  \
# 0               113      CSS 2025-09-06 22:08:06+00:00
# 1               113      CSS 2025-09-06 22:08:06+00:00
# 2               113      CSS 2025-09-06 22:08:06+00:00
# 3               113      CSS 2025-09-06 22:08:06+00:00
# 4               113      CSS 2025-09-06 22:08:06+00:00
# ...             ...      ...                       ...
# 4044           1367   Python 2025-08-04 15:10:45+00:00
# 4045           1367   Python 2025-08-04 15:10:45+00:00
# 4046           1367   Python 2025-08-04 15:10:45+00:00
# 4047           1367   Python 2025-08-04 15:10:45+00:00
# 4048           1362        C 2025-11-04 10:38:17+00:00
#
#                repo_updated_at release_name  \
# 0    2026-01-09 15:00:36+00:00       v2.1.4
# 1    2026-01-09 15:00:36+00:00       v2.1.3
# 2    2026-01-09 15:00:36+00:00       v2.1.2
# 3    2026-01-09 15:00:36+00:00       v2.1.1
# 4    2026-01-09 15:00:36+00:00       v2.1.0
# ...                        ...          ...
# 4044 2026-01-09 22:45:43+00:00       v1.2.0
# 4045 2026-01-09 22:45:43+00:00       v1.1.0
# 4046 2026-01-09 22:45:43+00:00       v1.0.0
# 4047 2026-01-09 22:45:43+00:00       v0.2.0
# 4048 2026-01-09 23:46:56+00:00   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos   author_type              published_at  \
# 0                      21          User 2026-01-08 20:07:56+00:00
# 1                      21          User 2026-01-05 23:56:48+00:00
# 2                      21          User 2026-01-03 22:20:14+00:00
# 3                      21          User 2026-01-02 20:03:09+00:00
# 4                      21          User 2026-01-02 14:25:38+00:00
# ...                   ...           ...                       ...
# 4044                    1          User 2025-10-04 11:01:46+00:00
# 4045                    1          User 2025-09-20 13:40:38+00:00
# 4046                    1          User 2025-09-16 17:21:47+00:00
# 4047                    1          User 2025-09-13 10:07:39+00:00
# 4048                  440  Organization 2025-12-04 10:29:19+00:00
#
#       first_week_star   date_only  is_trending
# 0                   3  2026-01-08         True
# 1                  11  2026-01-05         True
# 2                  12  2026-01-03         True
# 3                  14  2026-01-02         True
# 4                  15  2026-01-02         True
# ...               ...         ...          ...
# 4044               61  2025-10-04         True
# 4045               32  2025-09-20        False
# 4046               63  2025-09-16         True
# 4047              125  2025-09-13         True
# 4048               20  2025-12-04         True
#
# [4049 rows x 16 columns]

# %%
# Calculate the duration of a repository
release_df['repo_duration'] = (release_df['repo_updated_at'] - release_df['repo_created_at']).dt.days
release_df = release_df.drop(columns=['repo_updated_at', 'repo_created_at'])
release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language release_name  \
# 0               113      CSS       v2.1.4
# 1               113      CSS       v2.1.3
# 2               113      CSS       v2.1.2
# 3               113      CSS       v2.1.1
# 4               113      CSS       v2.1.0
# ...             ...      ...          ...
# 4044           1367   Python       v1.2.0
# 4045           1367   Python       v1.1.0
# 4046           1367   Python       v1.0.0
# 4047           1367   Python       v0.2.0
# 4048           1362        C   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos   author_type              published_at  \
# 0                      21          User 2026-01-08 20:07:56+00:00
# 1                      21          User 2026-01-05 23:56:48+00:00
# 2                      21          User 2026-01-03 22:20:14+00:00
# 3                      21          User 2026-01-02 20:03:09+00:00
# 4                      21          User 2026-01-02 14:25:38+00:00
# ...                   ...           ...                       ...
# 4044                    1          User 2025-10-04 11:01:46+00:00
# 4045                    1          User 2025-09-20 13:40:38+00:00
# 4046                    1          User 2025-09-16 17:21:47+00:00
# 4047                    1          User 2025-09-13 10:07:39+00:00
# 4048                  440  Organization 2025-12-04 10:29:19+00:00
#
#       first_week_star   date_only  is_trending  repo_duration
# 0                   3  2026-01-08         True            124
# 1                  11  2026-01-05         True            124
# 2                  12  2026-01-03         True            124
# 3                  14  2026-01-02         True            124
# 4                  15  2026-01-02         True            124
# ...               ...         ...          ...            ...
# 4044               61  2025-10-04         True            158
# 4045               32  2025-09-20        False            158
# 4046               63  2025-09-16         True            158
# 4047              125  2025-09-13         True            158
# 4048               20  2025-12-04         True             66
#
# [4049 rows x 15 columns]

# %%
# one-hot author type
release_df['org_author'] = (release_df['author_type'] == 'Organization').astype(int)
release_df['user_author'] = (release_df['author_type'] == 'User').astype(int)
release_df = release_df.drop(columns=['author_type'])
release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language release_name  \
# 0               113      CSS       v2.1.4
# 1               113      CSS       v2.1.3
# 2               113      CSS       v2.1.2
# 3               113      CSS       v2.1.1
# 4               113      CSS       v2.1.0
# ...             ...      ...          ...
# 4044           1367   Python       v1.2.0
# 4045           1367   Python       v1.1.0
# 4046           1367   Python       v1.0.0
# 4047           1367   Python       v0.2.0
# 4048           1362        C   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos              published_at  first_week_star  \
# 0                      21 2026-01-08 20:07:56+00:00                3
# 1                      21 2026-01-05 23:56:48+00:00               11
# 2                      21 2026-01-03 22:20:14+00:00               12
# 3                      21 2026-01-02 20:03:09+00:00               14
# 4                      21 2026-01-02 14:25:38+00:00               15
# ...                   ...                       ...              ...
# 4044                    1 2025-10-04 11:01:46+00:00               61
# 4045                    1 2025-09-20 13:40:38+00:00               32
# 4046                    1 2025-09-16 17:21:47+00:00               63
# 4047                    1 2025-09-13 10:07:39+00:00              125
# 4048                  440 2025-12-04 10:29:19+00:00               20
#
#        date_only  is_trending  repo_duration  org_author  user_author
# 0     2026-01-08         True            124           0            1
# 1     2026-01-05         True            124           0            1
# 2     2026-01-03         True            124           0            1
# 3     2026-01-02         True            124           0            1
# 4     2026-01-02         True            124           0            1
# ...          ...          ...            ...         ...          ...
# 4044  2025-10-04         True            158           0            1
# 4045  2025-09-20        False            158           0            1
# 4046  2025-09-16         True            158           0            1
# 4047  2025-09-13         True            158           0            1
# 4048  2025-12-04         True             66           1            0
#
# [4049 rows x 16 columns]

# %%
# whether release publish date is weekday or weekend
release_df['publish_is_weekday'] = (release_df['published_at'].dt.dayofweek <= 4).astype(int)
release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers language release_name  \
# 0               113      CSS       v2.1.4
# 1               113      CSS       v2.1.3
# 2               113      CSS       v2.1.2
# 3               113      CSS       v2.1.1
# 4               113      CSS       v2.1.0
# ...             ...      ...          ...
# 4044           1367   Python       v1.2.0
# 4045           1367   Python       v1.1.0
# 4046           1367   Python       v1.0.0
# 4047           1367   Python       v0.2.0
# 4048           1362        C   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos              published_at  first_week_star  \
# 0                      21 2026-01-08 20:07:56+00:00                3
# 1                      21 2026-01-05 23:56:48+00:00               11
# 2                      21 2026-01-03 22:20:14+00:00               12
# 3                      21 2026-01-02 20:03:09+00:00               14
# 4                      21 2026-01-02 14:25:38+00:00               15
# ...                   ...                       ...              ...
# 4044                    1 2025-10-04 11:01:46+00:00               61
# 4045                    1 2025-09-20 13:40:38+00:00               32
# 4046                    1 2025-09-16 17:21:47+00:00               63
# 4047                    1 2025-09-13 10:07:39+00:00              125
# 4048                  440 2025-12-04 10:29:19+00:00               20
#
#        date_only  is_trending  repo_duration  org_author  user_author  \
# 0     2026-01-08         True            124           0            1
# 1     2026-01-05         True            124           0            1
# 2     2026-01-03         True            124           0            1
# 3     2026-01-02         True            124           0            1
# 4     2026-01-02         True            124           0            1
# ...          ...          ...            ...         ...          ...
# 4044  2025-10-04         True            158           0            1
# 4045  2025-09-20        False            158           0            1
# 4046  2025-09-16         True            158           0            1
# 4047  2025-09-13         True            158           0            1
# 4048  2025-12-04         True             66           1            0
#
#       publish_is_weekday
# 0                      1
# 1                      1
# 2                      0
# 3                      1
# 4                      1
# ...                  ...
# 4044                   0
# 4045                   0
# 4046                   1
# 4047                   0
# 4048                   1
#
# [4049 rows x 17 columns]

# %%
# one-hot programming language
top_n = 20
top_languages = release_df['language'].value_counts().head(top_n).index
release_df['language_group'] = release_df['language'].where(release_df['language'].isin(top_languages), 'Other')
print("Language Distribution:")
print(release_df['language_group'].value_counts(normalize=True).head(15))

release_df = pd.concat([release_df.drop(['language', 'language_group'], axis=1), 
                pd.get_dummies(release_df['language_group'], prefix='language_')], axis=1)
release_df.columns = release_df.columns.str.replace('C#', 'Csharp').str.replace('C++', 'Cplusplus')
release_df
# Out:
# Language Distribution:
# language_group
# TypeScript    0.298345
# Python        0.214868
# Go            0.076809
# JavaScript    0.067177
# Rust          0.065942
# Other         0.048160
# C#            0.036058
# Kotlin        0.035564
# Swift         0.021487
# C             0.019017
# Vue           0.016794
# Java          0.016547
# PHP           0.012349
# Shell         0.010620
# C++           0.010373
# Name: proportion, dtype: float64
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers release_name  \
# 0               113       v2.1.4
# 1               113       v2.1.3
# 2               113       v2.1.2
# 3               113       v2.1.1
# 4               113       v2.1.0
# ...             ...          ...
# 4044           1367       v1.2.0
# 4045           1367       v1.1.0
# 4046           1367       v1.0.0
# 4047           1367       v0.2.0
# 4048           1362   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos              published_at  first_week_star  ...  \
# 0                      21 2026-01-08 20:07:56+00:00                3  ...
# 1                      21 2026-01-05 23:56:48+00:00               11  ...
# 2                      21 2026-01-03 22:20:14+00:00               12  ...
# 3                      21 2026-01-02 20:03:09+00:00               14  ...
# 4                      21 2026-01-02 14:25:38+00:00               15  ...
# ...                   ...                       ...              ...  ...
# 4044                    1 2025-10-04 11:01:46+00:00               61  ...
# 4045                    1 2025-09-20 13:40:38+00:00               32  ...
# 4046                    1 2025-09-16 17:21:47+00:00               63  ...
# 4047                    1 2025-09-13 10:07:39+00:00              125  ...
# 4048                  440 2025-12-04 10:29:19+00:00               20  ...
#
#      language__Other  language__PHP  language__Python  language__QML  \
# 0              False          False             False          False
# 1              False          False             False          False
# 2              False          False             False          False
# 3              False          False             False          False
# 4              False          False             False          False
# ...              ...            ...               ...            ...
# 4044           False          False              True          False
# 4045           False          False              True          False
# 4046           False          False              True          False
# 4047           False          False              True          False
# 4048           False          False             False          False
#
#       language__Rust  language__Shell  language__Svelte  language__Swift  \
# 0              False            False             False            False
# 1              False            False             False            False
# 2              False            False             False            False
# 3              False            False             False            False
# 4              False            False             False            False
# ...              ...              ...               ...              ...
# 4044           False            False             False            False
# 4045           False            False             False            False
# 4046           False            False             False            False
# 4047           False            False             False            False
# 4048           False            False             False            False
#
#       language__TypeScript  language__Vue
# 0                    False          False
# 1                    False          False
# 2                    False          False
# 3                    False          False
# 4                    False          False
# ...                    ...            ...
# 4044                 False          False
# 4045                 False          False
# 4046                 False          False
# 4047                 False          False
# 4048                 False          False
#
# [4049 rows x 37 columns]

# %%
# # Normalization
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# need_scaling = [
#     'repo_stars',
#     'repo_forks',
#     'repo_watchers',
#     'author_followers',
#     'author_public_repos',
#     'repo_duration'
# ]
# scaled_features = scaler.fit_transform(release_df[need_scaling])
# release_df_scaled = pd.DataFrame(scaled_features, columns=need_scaling, index=release_df.index)
# for col in need_scaling:
#     release_df[col] = release_df_scaled[col]
# release_df
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4   -1.824037   -0.368420
# 1     HANCORE-linux/waybar-themes/v2.1.3   -1.824037   -0.368420
# 2     HANCORE-linux/waybar-themes/v2.1.2   -1.824037   -0.368420
# 3     HANCORE-linux/waybar-themes/v2.1.1   -1.824037   -0.368420
# 4     HANCORE-linux/waybar-themes/v2.1.0   -1.824037   -0.368420
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0   -0.485108   -0.307315
# 4045       whyisdifficult/jiratui/v1.1.0   -0.485108   -0.307315
# 4046       whyisdifficult/jiratui/v1.0.0   -0.485108   -0.307315
# 4047       whyisdifficult/jiratui/v0.2.0   -0.485108   -0.307315
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1   -0.490447   -0.268145
#
#       repo_watchers                                             topics  \
# 0         -1.824037                                                 []
# 1         -1.824037                                                 []
# 2         -1.824037                                                 []
# 3         -1.824037                                                 []
# 4         -1.824037                                                 []
# ...             ...                                                ...
# 4044      -0.485108  ['atlassian', 'atlassian-jira', 'cli', 'develo...
# 4045      -0.485108  ['atlassian', 'atlassian-jira', 'cli', 'develo...
# 4046      -0.485108  ['atlassian', 'atlassian-jira', 'cli', 'develo...
# 4047      -0.485108  ['atlassian', 'atlassian-jira', 'cli', 'develo...
# 4048      -0.490447                                                 []
#
#      release_name                                       release_body  \
# 0          v2.1.4  # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...
# 1          v2.1.3  ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...
# 2          v2.1.2  # Changes\r\n#### V3-min3\r\n- reworked entire...
# 3          v2.1.1  # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...
# 4          v2.1.0  # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...
# ...           ...                                                ...
# 4044       v1.2.0  ## What's Changed\r\n\r\n* Add completions Sub...
# 4045       v1.1.0  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...
# 4046       v1.0.0  ## What's Changed\r\n\r\n### Breaking Changes\...
# 4047       v0.2.0  ## What's Changed\r\n\r\n### Application\r\n* ...
# 4048   v3.1.0 RC1  ## What's Changed (since initial release)\r\n*...
#
#       author_followers  author_public_repos              published_at  ...  \
# 0            -0.235755            -0.149384 2026-01-08 20:07:56+00:00  ...
# 1            -0.235755            -0.149384 2026-01-05 23:56:48+00:00  ...
# 2            -0.235755            -0.149384 2026-01-03 22:20:14+00:00  ...
# 3            -0.235755            -0.149384 2026-01-02 20:03:09+00:00  ...
# 4            -0.235755            -0.149384 2026-01-02 14:25:38+00:00  ...
# ...                ...                  ...                       ...  ...
# 4044         -0.237363            -0.178537 2025-10-04 11:01:46+00:00  ...
# 4045         -0.237363            -0.178537 2025-09-20 13:40:38+00:00  ...
# 4046         -0.237363            -0.178537 2025-09-16 17:21:47+00:00  ...
# 4047         -0.237363            -0.178537 2025-09-13 10:07:39+00:00  ...
# 4048         -0.077728             0.461381 2025-12-04 10:29:19+00:00  ...
#
#       language__Other  language__PHP  language__Python  language__QML  \
# 0               False          False             False          False
# 1               False          False             False          False
# 2               False          False             False          False
# 3               False          False             False          False
# 4               False          False             False          False
# ...               ...            ...               ...            ...
# 4044            False          False              True          False
# 4045            False          False              True          False
# 4046            False          False              True          False
# 4047            False          False              True          False
# 4048            False          False             False          False
#
#       language__Rust  language__Shell  language__Svelte  language__Swift  \
# 0              False            False             False            False
# 1              False            False             False            False
# 2              False            False             False            False
# 3              False            False             False            False
# 4              False            False             False            False
# ...              ...              ...               ...              ...
# 4044           False            False             False            False
# 4045           False            False             False            False
# 4046           False            False             False            False
# 4047           False            False             False            False
# 4048           False            False             False            False
#
#       language__TypeScript  language__Vue
# 0                    False          False
# 1                    False          False
# 2                    False          False
# 3                    False          False
# 4                    False          False
# ...                    ...            ...
# 4044                 False          False
# 4045                 False          False
# 4046                 False          False
# 4047                 False          False
# 4048                 False          False
#
# [4049 rows x 36 columns]

# %%
# Check missing values
missing_values = release_df.isnull().sum()
missing_info = pd.DataFrame({
    'Missing nums': missing_values
})
print(missing_info[missing_info['Missing nums'] > 0])
# Out:
#               Missing nums
# release_name            73
# release_body           172

# %%
# Fill missing values
release_df_filled = release_df.copy()
release_df_filled['release_name'] = release_df_filled['release_name'].fillna('')
release_df_filled['release_body'] = release_df_filled['release_body'].fillna('')
release_df_filled
# Out:
#                                full_name  repo_stars  repo_forks  \
# 0     HANCORE-linux/waybar-themes/v2.1.4         113           1
# 1     HANCORE-linux/waybar-themes/v2.1.3         113           1
# 2     HANCORE-linux/waybar-themes/v2.1.2         113           1
# 3     HANCORE-linux/waybar-themes/v2.1.1         113           1
# 4     HANCORE-linux/waybar-themes/v2.1.0         113           1
# ...                                  ...         ...         ...
# 4044       whyisdifficult/jiratui/v1.2.0        1367          40
# 4045       whyisdifficult/jiratui/v1.1.0        1367          40
# 4046       whyisdifficult/jiratui/v1.0.0        1367          40
# 4047       whyisdifficult/jiratui/v0.2.0        1367          40
# 4048   Snowflake-Labs/pg_lake/v3.1.0-rc1        1362          65
#
#       repo_watchers release_name  \
# 0               113       v2.1.4
# 1               113       v2.1.3
# 2               113       v2.1.2
# 3               113       v2.1.1
# 4               113       v2.1.0
# ...             ...          ...
# 4044           1367       v1.2.0
# 4045           1367       v1.1.0
# 4046           1367       v1.0.0
# 4047           1367       v0.2.0
# 4048           1362   v3.1.0 RC1
#
#                                            release_body  author_followers  \
# 0     # 🎉 New Waybar Release  "V2.1a & V2.1b – Oxoca...                52
# 1     ## 🔧 Changes\r\n### V3-min3\r\n- Adjusted back...                52
# 2     # Changes\r\n#### V3-min3\r\n- reworked entire...                52
# 3     # 🎉 New Waybar Release  "V6.fa"\r\n- Changed f...                52
# 4     # 🎉 New Waybar Release  "V6.f"\r\n- Cycles thr...                52
# ...                                                 ...               ...
# 4044  ## What's Changed\r\n\r\n* Add completions Sub...                30
# 4045  ## What's Changed\r\n\r\n## Added\r\n\r\n* Add...                30
# 4046  ## What's Changed\r\n\r\n### Breaking Changes\...                30
# 4047  ## What's Changed\r\n\r\n### Application\r\n* ...                30
# 4048  ## What's Changed (since initial release)\r\n*...              2214
#
#       author_public_repos              published_at  first_week_star  ...  \
# 0                      21 2026-01-08 20:07:56+00:00                3  ...
# 1                      21 2026-01-05 23:56:48+00:00               11  ...
# 2                      21 2026-01-03 22:20:14+00:00               12  ...
# 3                      21 2026-01-02 20:03:09+00:00               14  ...
# 4                      21 2026-01-02 14:25:38+00:00               15  ...
# ...                   ...                       ...              ...  ...
# 4044                    1 2025-10-04 11:01:46+00:00               61  ...
# 4045                    1 2025-09-20 13:40:38+00:00               32  ...
# 4046                    1 2025-09-16 17:21:47+00:00               63  ...
# 4047                    1 2025-09-13 10:07:39+00:00              125  ...
# 4048                  440 2025-12-04 10:29:19+00:00               20  ...
#
#      language__Other  language__PHP  language__Python  language__QML  \
# 0              False          False             False          False
# 1              False          False             False          False
# 2              False          False             False          False
# 3              False          False             False          False
# 4              False          False             False          False
# ...              ...            ...               ...            ...
# 4044           False          False              True          False
# 4045           False          False              True          False
# 4046           False          False              True          False
# 4047           False          False              True          False
# 4048           False          False             False          False
#
#       language__Rust  language__Shell  language__Svelte  language__Swift  \
# 0              False            False             False            False
# 1              False            False             False            False
# 2              False            False             False            False
# 3              False            False             False            False
# 4              False            False             False            False
# ...              ...              ...               ...              ...
# 4044           False            False             False            False
# 4045           False            False             False            False
# 4046           False            False             False            False
# 4047           False            False             False            False
# 4048           False            False             False            False
#
#       language__TypeScript  language__Vue
# 0                    False          False
# 1                    False          False
# 2                    False          False
# 3                    False          False
# 4                    False          False
# ...                    ...            ...
# 4044                 False          False
# 4045                 False          False
# 4046                 False          False
# 4047                 False          False
# 4048                 False          False
#
# [4049 rows x 37 columns]

# %% [markdown]
# ## Create Feature Groups and insert DataFrames

# %%
fs = project.get_feature_store()

# %%
release_fg = fs.get_or_create_feature_group(
    name='release_info',
    description='Github release information',
    version=1,
    primary_key=['full_name'],
    event_time="published_at"
)

# %%
release_fg.insert(release_df_filled)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1342613/fs/1331268/fg/1911315
# Uploading Dataframe: 100.00% |██████████| Rows 4049/4049 | Elapsed Time: 00:05 | Remaining Time: 00:00
# Launching job: release_info_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1342613/jobs/named/release_info_1_offline_fg_materialization/executions
# (Job('release_info_1_offline_fg_materialization', 'SPARK'), None)
